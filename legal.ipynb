# %% [markdown]
# # LEGAL

# %%
vinoth123=5
print(vinoth123)
# Out:
# 5

# %%
Vin_oth=34
print(Vin_oth)
# Out:
# 34

# %%
_vinoth=23
print(_vinoth)
# Out:
# 23

# %%
vinoth_sum233="Hello World !"
print(vinoth_sum233)
# Out:
# Hello World !

# %%
kumar=90
print(kumar)
# Out:
# 90

# %% [markdown]
# # ILLEGAL

# %%
12var=3;
print(12var)
# Out:
#   Cell In[1], line 1
#     12var=3;
#      ^
# SyntaxError: invalid decimal literal

# %%
-vinoth=0
print(-vinoth)
# Out:
#   Cell In[2], line 1
#     -vinoth=0
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
##vi=8
print(##vi)
# Out:
#   Cell In[3], line 2
#     print(##vi)
#                ^
# _IncompleteInputError: incomplete input

# %%
vino-th=7
print(vino-th)
# Out:
#   Cell In[4], line 1
#     vino-th=7
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?
