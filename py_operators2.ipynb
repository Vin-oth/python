# %% [markdown]
# # IDENTITY OPERATORS

# %%
a=5
b=a
print(a is b)
# Out:
# True

# %%
x=None
print(x is None)
# Out:
# True

# %%
x=[1,2,3]
y=[1,2,3]
print(x is y)
# Out:
# False

# %%
s1="vinoth"
s2=s1
print(s1 is s2)
# Out:
# True

# %%
x=[1,2,3]
y=[1,2,3]
print(x is not y)
# Out:
# True

# %%
x=5 
print(x is not None)
# Out:
# True

# %% [markdown]
# # MEMBERSHIP OPERATORS

# %%
a =[1,2,3,4]

print(2 in a)
# Out:
# True

# %%
text="Python"
print("Py" in text)
# Out:
# True

# %%
text="Python"
print('x' not in text)
# Out:
# True
